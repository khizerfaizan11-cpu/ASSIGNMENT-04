# %% [markdown]
# 1. Write a Python program to create a class representing a Circle. Include methods to calculate its area and perimeter.

# %%
import math

class Circle:
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.radius

radius = float(input("Enter the radius of the circle: "))
circle = Circle(radius)

print("Area of the circle:", circle.area())
print("Perimeter of the circle:", circle.perimeter())
# Out:
# Area of the circle: 12.566370614359172
# Perimeter of the circle: 12.566370614359172

# %% [markdown]
# 2. Write a Python program to create a person class. Include attributes like name, country and date of birth. Implement a method to determine the person's age.

# %%
from datetime import datetime

class Person:
    def __init__(self, name, country, date_of_birth):
        self.name = name
        self.country = country
        
        self.date_of_birth = datetime.strptime(date_of_birth, "%Y-%m-%d")

    def calculate_age(self):
        today = datetime.today()
        age = today.year - self.date_of_birth.year

        if (today.month, today.day) < (self.date_of_birth.month, self.date_of_birth.day):
            age -= 1

        return age

person = Person("khizer", "Pakistan", "2010-04-12")

print("Name:", person.name)
print("Country:", person.country)
print("Date of Birth:", person.date_of_birth.strftime("%Y-%m-%d"))
print("Age:", person.calculate_age(), "years")
# Out:
# Name: khizer
# Country: Pakistan
# Date of Birth: 2010-04-12
# Age: 16 years

# %% [markdown]
# 3. Write a Python program to create a calculator class. Include methods for basic arithmetic operations.

# %%
class Calculator:
    def add(self, a, b):
        return a + b

    def subtract(self, a, b):
        return a - b

    def multiply(self, a, b):
        return a * b

    def divide(self, a, b):
        if b == 0:
            return "Error! Division by zero is not allowed."
        return a / b

calc = Calculator()

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("Addition:", calc.add(num1, num2))
print("Subtraction:", calc.subtract(num1, num2))
print("Multiplication:", calc.multiply(num1, num2))
print("Division:", calc.divide(num1, num2))
# Out:
# Addition: 37.0
# Subtraction: 9.0
# Multiplication: 322.0
# Division: 1.6428571428571428

# %% [markdown]
# ## LISTS

# %% [markdown]
# 4. Create a list of  15 student names and print each name using a for loop.

# %%
students = [
    "Atiya", "Adeena", "Ayesha", "Fatima", "khizer",
    "Zain", "Sara", "kaif", "Maryam", "Bilal",
    "Hina", "Hamza", "abdullah", "Amna", "Daniyal"
]

for student in students:
    print(student)
# Out:
# Atiya
# Adeena
# Ayesha
# Fatima
# khizer
# Zain
# Sara
# kaif
# Maryam
# Bilal
# Hina
# Hamza
# abdullah
# Amna
# Daniyal

# %% [markdown]
# 5. Create a list of numbers from 1 to 10. Print only the even numbers.

# %%
numbers = list(range(1, 11))

for num in numbers:
    if num % 2 == 0:
        print(num)
# Out:
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# 6. Create a list of five numbers and find the largest and smallest number without using the max() & min() function.

# %%
numbers = [12, 63, 2, 23, 19]

largest = numbers[0]
smallest = numbers[0]

for num in numbers:
    if num > largest:
        largest = num
    if num < smallest:
        smallest = num

print("Largest number:", largest)
print("Smallest number:", smallest)
# Out:
# Largest number: 63
# Smallest number: 2

# %% [markdown]
# 7. Count how many times "Apple" appears in the following list.
# fruits = ["Apple", "Banana", "Apple", "Orange", "Apple"]

# %%
fruits = ["Apple", "Banana", "Apple", "Orange", "Apple", "Apple"]

count = 0

for fruit in fruits:
    if fruit == "Apple":
        count += 1

print("Apple appears", count, "times.")
# Out:
# Apple appears 4 times.

# %% [markdown]
# 8. Create a list of numbers and sort it in:
# - Ascending order
# - Descending order

# %%
numbers = [72, 32, 45, 55, 21, 87]

ascending = sorted(numbers)
print("Ascending order:", ascending)

descending = sorted(numbers, reverse=True)
print("Descending order:", descending)
# Out:
# Ascending order: [21, 32, 45, 55, 72, 87]
# Descending order: [87, 72, 55, 45, 32, 21]

# %% [markdown]
# 9. Copy one list into another list and print both lists.

# %%
list1 = [11, 22, 33, 44, 55]

list2 = list1.copy()

print("Original List:", list1)
print("Copied List:", list2)
# Out:
# Original List: [11, 22, 33, 44, 55]
# Copied List: [11, 22, 33, 44, 55]

# %% [markdown]
# 10. Create the following nested list:
#
# - students = [
# -     ["Ali", 20],
# -     ["Ahmed", 18],
# -     ["Sara", 19]
# - ]
# - Print:
# - All student names
# - All student ages

# %%
students = [
    ["Ali", 20],
    ["Ahmed", 18],
    ["Sara", 19]
]

print("Student Names:")
for student in students:
    print(student[0])

# Print all student ages
print("\nStudent Ages:")
for student in students:
    print(student[1])
# Out:
# Student Names:
# Ali
# Ahmed
# Sara
#
# Student Ages:
# 20
# 18
# 19

# %% [markdown]
# 11. Create a list of 10 numbers. Print:
# - Total numbers
# - Sum
# - Average
# - Maximum value
# - Minimum value

# %%
numbers = [17, 2, 28, 1, 38, 19, 12, 27, 16, 9]

total_numbers = len(numbers)

total_sum = 0
for num in numbers:
    total_sum += num

average = total_sum / total_numbers

maximum = numbers[0]
minimum = numbers[0]

for num in numbers:
    if num > maximum:
        maximum = num
    if num < minimum:
        minimum = num

print("Total numbers:", total_numbers)
print("Sum:", total_sum)
print("Average:", average)
print("Maximum value:", maximum)
print("Minimum value:", minimum)
# Out:
# Total numbers: 10
# Sum: 169
# Average: 16.9
# Maximum value: 38
# Minimum value: 1

# %% [markdown]
# 12. Perform the following operations on a list:
# - Append one item
# - Insert one item
# - Remove one item
# - Pop one item
# - Print the list after each operation.

# %%
numbers = [10, 20, 30, 40, 50]

numbers.append(30)
print("After append:", numbers)

numbers.insert(2, 25)
print("After insert:", numbers)

numbers.remove(10)
print("After remove:", numbers)

numbers.pop()
print("After pop:", numbers)
# Out:
# After append: [10, 20, 30, 40, 50, 30]
# After insert: [10, 20, 25, 30, 40, 50, 30]
# After remove: [20, 25, 30, 40, 50, 30]
# After pop: [20, 25, 30, 40, 50]
